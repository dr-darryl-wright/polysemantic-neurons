# %%
import itertools
import matplotlib

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K

from tqdm import tqdm
from scipy.spatial import distance

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
np.random.seed(0)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train / 255.
x_test = x_test / 255.

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

y = np.argmax(y_train, axis=1)
x_train_1s = x_train[np.where(y==1)]
x_train_8s = x_train[np.where(y==8)]
y_train_1s = y[np.where(y==1)]
y_train_8s = y[np.where(y==8)]

x_train_1s_8s = np.concatenate((x_train_1s, x_train_8s))
y_train_1s_8s = np.concatenate((y_train_1s, y_train_8s))

y_train_1s_8s[np.where(y_train_1s_8s==8)] = 0

order = np.random.permutation(len(x_train_1s_8s))

x_train_1s_8s = x_train_1s_8s[order]
y_train_1s_8s = y_train_1s_8s[order]

print(y_train_1s_8s)

y_train_1s_8s = tf.keras.utils.to_categorical(y_train_1s_8s, 2)

x_train_1s_8s_reshape = [x_train_1s_8s[i].reshape((784)) for i in range(len(x_train_1s_8s))]
print(np.array(x_train_1s_8s_reshape).shape)
# Out:
# [0 1 1 ... 0 0 1]
# (12593, 784)

# %%
n_hidden_neurons = 4
lr = 0.001
epochs = 200
batch_size = 8
limit = 256
alpha = 0.0 # ignore polysemantic term in loss function.

# %%
i = tf.keras.layers.Input(shape=(28*28,))
i2 = tf.keras.layers.Input(shape=(2,))
e = tf.keras.layers.Dense(n_hidden_neurons, activation='relu', name='dense_1')(i)
o = tf.keras.layers.Dense(2, activation='softmax', name='softmax')(e)
model = tf.keras.Model(inputs=[i, i2], outputs=o)
# Out:
# 2022-05-15 21:07:51.458356: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def calculate_term(e, c0, c1):
  a = K.expand_dims(e[c0] / (K.max(K.abs(e[c0])) + 1e-9))
  b = K.expand_dims(e[c1] / (K.max(K.abs(e[c1])) + 1e-9))
  if c0==c1:
    return 0
  else:
    return K.dot(K.transpose(a), b)

# %%
#https://stackoverflow.com/questions/62454500/how-to-use-tensorflow-custom-loss-for-a-keras-model
def my_loss(y_true, y_pred, e, c0, c1, alpha):
    p_loss = 0
    for i in range(len(c0)):
      p_loss += calculate_term(e, c0[i], c1[i])

    loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(y_true=y_true, 
                                                                      y_pred=y_pred)
    loss += alpha * (p_loss / len(c0))
    return loss

# %%
c0, c1 = [], []
for c in list(itertools.combinations(range(batch_size), 2)):
    c0.append(c[0])
    c1.append(c[1])

# %%
print(len(c0))
# Out:
# 28

# %%
model.add_loss(my_loss(i2, o, e, np.array(c0, dtype='int32'), np.array(c1, dtype='int32'), alpha))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), 
              loss=None)

# %%
model.fit([np.array(x_train_1s_8s_reshape)[:limit], y_train_1s_8s[:limit]],
          y=None,
          batch_size=batch_size,
          epochs=epochs)
# Out:
# 2022-05-15 21:07:53.796248: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 32/32 [==============================] - 5s 3ms/step - loss: 0.5712
# Epoch 2/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3271
# Epoch 3/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1989
# Epoch 4/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1450
# Epoch 5/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1170
# Epoch 6/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0980
# Epoch 7/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0839
# Epoch 8/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0733
# Epoch 9/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0649
# Epoch 10/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0611
# Epoch 11/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0527
# Epoch 12/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0485
# Epoch 13/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0435
# Epoch 14/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 15/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0363
# Epoch 16/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0348
# Epoch 17/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0301
# Epoch 18/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0280
# Epoch 19/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0263
# Epoch 20/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0238
# Epoch 21/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0224
# Epoch 22/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0203
# Epoch 23/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 24/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 25/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0159
# Epoch 26/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0149
# Epoch 27/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 28/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 29/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 30/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 31/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 32/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 33/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 34/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 35/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 36/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 37/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 38/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 39/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 40/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 41/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 42/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 43/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 44/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 45/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 46/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 47/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 48/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 49/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 50/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 51/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 52/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 53/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 54/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 55/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 56/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 57/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 58/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 59/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 60/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 61/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 62/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 63/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 64/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 65/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 66/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 67/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 68/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 69/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 70/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 71/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 72/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 73/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 74/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 75/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 76/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 77/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 78/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 79/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 80/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 81/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 82/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 83/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 84/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 85/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 86/200
# 32/32 [==============================] - 0s 2ms/step - loss: 9.8042e-04
# Epoch 87/200
# 32/32 [==============================] - 0s 2ms/step - loss: 9.6389e-04
# Epoch 88/200
# 32/32 [==============================] - 0s 2ms/step - loss: 9.2428e-04
# Epoch 89/200
# 32/32 [==============================] - 0s 3ms/step - loss: 8.9580e-04
# Epoch 90/200
# 32/32 [==============================] - 0s 3ms/step - loss: 8.7480e-04
# Epoch 91/200
# 32/32 [==============================] - 0s 2ms/step - loss: 8.4774e-04
# Epoch 92/200
# 32/32 [==============================] - 0s 3ms/step - loss: 8.2373e-04
# Epoch 93/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.9771e-04
# Epoch 94/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7513e-04
# Epoch 95/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.5215e-04
# Epoch 96/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.4372e-04
# Epoch 97/200
# 32/32 [==============================] - 0s 4ms/step - loss: 7.1150e-04
# Epoch 98/200
# 32/32 [==============================] - 0s 4ms/step - loss: 6.9355e-04
# Epoch 99/200
# 32/32 [==============================] - 0s 3ms/step - loss: 6.7214e-04
# Epoch 100/200
# 32/32 [==============================] - 0s 3ms/step - loss: 6.5592e-04
# Epoch 101/200
# 32/32 [==============================] - 0s 3ms/step - loss: 6.4455e-04
# Epoch 102/200
# 32/32 [==============================] - 0s 6ms/step - loss: 6.2265e-04
# Epoch 103/200
# 32/32 [==============================] - 0s 4ms/step - loss: 6.0275e-04
# Epoch 104/200
# 32/32 [==============================] - 0s 3ms/step - loss: 5.8633e-04
# Epoch 105/200
# 32/32 [==============================] - 0s 3ms/step - loss: 5.7798e-04
# Epoch 106/200
# 32/32 [==============================] - 0s 2ms/step - loss: 5.5703e-04
# Epoch 107/200
# 32/32 [==============================] - 0s 2ms/step - loss: 5.4806e-04
# Epoch 108/200
# 32/32 [==============================] - 0s 2ms/step - loss: 5.3666e-04
# Epoch 109/200
# 32/32 [==============================] - 0s 2ms/step - loss: 5.1800e-04
# Epoch 110/200
# 32/32 [==============================] - 0s 2ms/step - loss: 5.0455e-04
# Epoch 111/200
# 32/32 [==============================] - 0s 2ms/step - loss: 4.9449e-04
# Epoch 112/200
# 32/32 [==============================] - 0s 2ms/step - loss: 4.7820e-04
# Epoch 113/200
# 32/32 [==============================] - 0s 2ms/step - loss: 4.7025e-04
# Epoch 114/200
# 32/32 [==============================] - 0s 2ms/step - loss: 4.5723e-04
# Epoch 115/200
# 32/32 [==============================] - 0s 2ms/step - loss: 4.4549e-04
# Epoch 116/200
# 32/32 [==============================] - 0s 2ms/step - loss: 4.3194e-04
# Epoch 117/200
# 32/32 [==============================] - 0s 3ms/step - loss: 4.2799e-04
# Epoch 118/200
# 32/32 [==============================] - 0s 2ms/step - loss: 4.1912e-04
# Epoch 119/200
# 32/32 [==============================] - 0s 2ms/step - loss: 4.0707e-04
# Epoch 120/200
# 32/32 [==============================] - 0s 2ms/step - loss: 3.9382e-04
# Epoch 121/200
# 32/32 [==============================] - 0s 2ms/step - loss: 3.9180e-04
# Epoch 122/200
# 32/32 [==============================] - 0s 3ms/step - loss: 3.7218e-04
# Epoch 123/200
# 32/32 [==============================] - 0s 2ms/step - loss: 3.6408e-04
# Epoch 124/200
# 32/32 [==============================] - 0s 3ms/step - loss: 3.5661e-04
# Epoch 125/200
# 32/32 [==============================] - 0s 3ms/step - loss: 3.5193e-04
# Epoch 126/200
# 32/32 [==============================] - 0s 3ms/step - loss: 3.3886e-04
# Epoch 127/200
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3384e-04
# Epoch 128/200
# 32/32 [==============================] - 0s 2ms/step - loss: 3.2431e-04
# Epoch 129/200
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1799e-04
# Epoch 130/200
# 32/32 [==============================] - 0s 3ms/step - loss: 3.1012e-04
# Epoch 131/200
# 32/32 [==============================] - 0s 3ms/step - loss: 3.0968e-04
# Epoch 132/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.9513e-04
# Epoch 133/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.8950e-04
# Epoch 134/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.8226e-04
# Epoch 135/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.7558e-04
# Epoch 136/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.7053e-04
# Epoch 137/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.6508e-04
# Epoch 138/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.5731e-04
# Epoch 139/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.5326e-04
# Epoch 140/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.4766e-04
# Epoch 141/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.4637e-04
# Epoch 142/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.3596e-04
# Epoch 143/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.3024e-04
# Epoch 144/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.2510e-04
# Epoch 145/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.2090e-04
# Epoch 146/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.1545e-04
# Epoch 147/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.1038e-04
# Epoch 148/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.0685e-04
# Epoch 149/200
# 32/32 [==============================] - 0s 3ms/step - loss: 2.0292e-04
# Epoch 150/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.9955e-04
# Epoch 151/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.9386e-04
# Epoch 152/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.9075e-04
# Epoch 153/200
# 32/32 [==============================] - 0s 4ms/step - loss: 1.8535e-04
# Epoch 154/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.8279e-04
# Epoch 155/200
# 32/32 [==============================] - 0s 5ms/step - loss: 1.8093e-04
# Epoch 156/200
# 32/32 [==============================] - 0s 5ms/step - loss: 1.7430e-04
# Epoch 157/200
# 32/32 [==============================] - 0s 4ms/step - loss: 1.7083e-04
# Epoch 158/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.6644e-04
# Epoch 159/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.6262e-04
# Epoch 160/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.5973e-04
# Epoch 161/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.5586e-04
# Epoch 162/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.5337e-04
# Epoch 163/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4939e-04
# Epoch 164/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4698e-04
# Epoch 165/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4889e-04
# Epoch 166/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4036e-04
# Epoch 167/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3761e-04
# Epoch 168/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3526e-04
# Epoch 169/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3190e-04
# Epoch 170/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3003e-04
# Epoch 171/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.2693e-04
# Epoch 172/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.2357e-04
# Epoch 173/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.2188e-04
# Epoch 174/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1939e-04
# Epoch 175/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1688e-04
# Epoch 176/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1443e-04
# Epoch 177/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1158e-04
# Epoch 178/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0965e-04
# Epoch 179/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0738e-04
# Epoch 180/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0634e-04
# Epoch 181/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0287e-04
# Epoch 182/200
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0153e-04
# Epoch 183/200
# 32/32 [==============================] - 0s 3ms/step - loss: 9.9369e-05
# Epoch 184/200
# 32/32 [==============================] - 0s 3ms/step - loss: 9.6963e-05
# Epoch 185/200
# 32/32 [==============================] - 0s 3ms/step - loss: 9.4928e-05
# Epoch 186/200
# 32/32 [==============================] - 0s 3ms/step - loss: 9.3903e-05
# Epoch 187/200
# 32/32 [==============================] - 0s 3ms/step - loss: 9.1657e-05
# Epoch 188/200
# 32/32 [==============================] - 0s 3ms/step - loss: 9.0158e-05
# Epoch 189/200
# 32/32 [==============================] - 0s 3ms/step - loss: 8.8159e-05
# Epoch 190/200
# 32/32 [==============================] - 0s 3ms/step - loss: 8.5915e-05
# Epoch 191/200
# 32/32 [==============================] - 0s 3ms/step - loss: 8.4655e-05
# Epoch 192/200
# 32/32 [==============================] - 0s 3ms/step - loss: 8.2842e-05
# Epoch 193/200
# 32/32 [==============================] - 0s 3ms/step - loss: 8.1362e-05
# Epoch 194/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.9701e-05
# Epoch 195/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7788e-05
# Epoch 196/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.6585e-05
# Epoch 197/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.5104e-05
# Epoch 198/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.3629e-05
# Epoch 199/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.2199e-05
# Epoch 200/200
# 32/32 [==============================] - 0s 3ms/step - loss: 7.0674e-05

# %%
embed = tf.keras.Model(inputs=i, outputs=e)

# %%
embed.layers[1].set_weights(model.layers[1].get_weights())
activations_by_class = {}
a = embed.predict(np.array(x_train_1s_8s_reshape))
for i in tqdm(range(len(x_train_1s_8s_reshape[:limit]))):
    try:
        activations_by_class[np.argmax(y_train_1s_8s, axis=1)[i]] += np.squeeze(a[i])
    except KeyError:
        activations_by_class[np.argmax(y_train_1s_8s, axis=1)[i]] = np.squeeze(a[i])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 256/256 [00:00<00:00, 7672.43it/s]

# %%
fig = plt.figure(figsize=(20,20))
for i,k in enumerate(activations_by_class.keys()):
    y_pos = np.arange(len(activations_by_class[k]))
    ax = fig.add_subplot(1, 2, i+1)
    ax.set_title(k)
    ax.barh(y_pos, np.squeeze(activations_by_class[k]), align='center')
    ax.plot([0,0],[-1,len(np.squeeze(activations_by_class[k]))], 'k-')
    ax.set_ylim(-1,len(np.squeeze(activations_by_class[k])))
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
W = embed.layers[1].get_weights()
fig = plt.figure(figsize=(20,20))
dim = int(np.ceil(np.sqrt(n_hidden_neurons)))
for j in range(n_hidden_neurons):
  x_j = W[0][:,j] / np.sqrt(np.sum(np.dot(W[0][:,j], W[0][:,j].T)))
  ax = fig.add_subplot(dim,dim,j+1)
  ax.imshow(x_j.reshape((28,28)))
  plt.axis('off')
plt.show()
